# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("skills.csv", names=['Skills', 'Freq'], index_col=0)
df
# Out:
#             Freq
# Skills
# NaN            0
# javascript     6
# java          13
# scala          1
# typescript     3
# sql            5
# python        14
# angular        2
# react.js       3
# node.js        3
# ebx            1
# c++           12
# cobra          1
# c#             7
# c              9
# ruby           1
# html5          1
# xml            1
# perl           1
# ajax           2
# qt             1
# oracle         3
# html           4
# css            3
# jquery         2
# aws            3
# vue.js         1
# sass           1
# webgl          1
# webpack        3
# matlab         1
# angularjs      1
# react          1
# .net           1
# asp.net        2
# nodej.js       1
# nosql          1
# go             1
# postgres       2
# kafka          1
# redshift       1
# heroku         1
# docker         1
# kubernetes     1
# redis          1
# postgresql     1
# netcore        1
# bootstrap      1

# %%
df.drop(df.loc[df['Freq']<=1].index, inplace=True)
df
# Out:
#             Freq
# Skills
# javascript     6
# java          13
# typescript     3
# sql            5
# python        14
# angular        2
# react.js       3
# node.js        3
# c++           12
# c#             7
# c              9
# ajax           2
# oracle         3
# html           4
# css            3
# jquery         2
# aws            3
# webpack        3
# asp.net        2
# postgres       2

# %%
df.sort_values(by=["Freq"], inplace = True)

# %%
df.plot(kind="bar", title="What Should I Learn?")
#plt.xticks(rotation=30, horizontalalignment="center")
plt.xlabel("Skills")
plt.ylabel("Frequency")
plt.show()

# %%
df
# Out:
#         Skills  Freq
# 38    postgres     2
# 7      angular     2
# 24      jquery     2
# 34     asp.net     2
# 19        ajax     2
# 29     webpack     3
# 4   typescript     3
# 25         aws     3
# 8     react.js     3
# 9      node.js     3
# 23         css     3
# 21      oracle     3
# 22        html     4
# 5          sql     5
# 1   javascript     6
# 13          c#     7
# 14           c     9
# 11         c++    12
# 2         java    13
# 6       python    14

# %%
d = dict(zip(list(, df[1][:]))
d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/k5/0999gcln3qq7gq3qm8lnjv6r0000gn/T/ipykernel_26138/2945338493.py in <module>
# ----> 1 d = dict(zip(df[0][:], df[1][:]))
#       2 d
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 0

# %%
list(df.index)
# Out:
# ['postgres',
#  'angular',
#  'jquery',
#  'asp.net',
#  'ajax',
#  'webpack',
#  'typescript',
#  'aws',
#  'react.js',
#  'node.js',
#  'css',
#  'oracle',
#  'html',
#  'sql',
#  'javascript',
#  'c#',
#  'c',
#  'c++',
#  'java',
#  'python']

# %%
list(df['Freq'])
# Out:
# [2, 2, 2, 2, 2, 3, 3, 3, 3, 3, 3, 3, 4, 5, 6, 7, 9, 12, 13, 14]
